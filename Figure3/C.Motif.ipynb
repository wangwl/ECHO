# %%
import re
import os
import glob
import pandas as pd
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('pdf', fonttype=42)
import seaborn as sns

# %%
known_motifs = glob.glob("*/DMR_bed/*/knownResults.txt")

# %%
motif_pvalue = defaultdict(dict)
for motif_result in known_motifs:
    result_df = pd.read_csv(motif_result, sep="\t", index_col=0)
    result_df.index = [x.split("/")[0] for x in result_df.index]
    
    cell_type = motif_result.split("/")[-4]
    hyp, cond = motif_result.split("/")[-2].split("_")[1:]
    for motif, row in result_df.iterrows():
        if row['P-value'] < 0.01:
            motif_pvalue[motif][f'{hyp}_{cell_type}_{cond}'] = row['P-value']

# %%
motif_pvalue_df = pd.DataFrame.from_dict(motif_pvalue, orient='index')

# %%
dense_motif = -np.log10(motif_pvalue_df.sort_index(axis=1).sort_index()).dropna(thresh=10).fillna(0)
sparse_motif = -np.log10(motif_pvalue_df.loc[~motif_pvalue_df.index.isin(dense_motif.index)]).sort_index(axis=1).sort_index().fillna(0)

# %%
sparse_motif = sparse_motif.loc[sparse_motif.astype(int).sum(axis=1)>5]

# %%
dense_motif['Motif'] = dense_motif.index
dense_motif_melt = dense_motif.melt(var_name='Group', id_vars='Motif', value_name='P-Value')
dense_motif_melt['Cell'] = [x.split("_")[1] for x in dense_motif_melt['Group']]

# %%
sparse_motif['Motif'] = sparse_motif.index
sparse_motif_melt = sparse_motif.melt(var_name='Group', id_vars='Motif', value_name='P-Value')
sparse_motif_melt['Cell'] = [x.split("_")[1] for x in sparse_motif_melt['Group']]

# %%
color_plate = sns.color_palette("tab10")

cell2color = {'B-Mem': color_plate[0],
             'B-Naive': color_plate[0],
             'Monocyte': color_plate[1],
              'Monocyte1': color_plate[1],
             'NK-cell1': color_plate[2],
             'NK-cell2': color_plate[2],
             'Tc-Mem': color_plate[3],
             'Tc-Naive': color_plate[4],
             'Th-Mem': color_plate[5],
             'Th-Naive': color_plate[6]}

# %%
dense_motif_melt.replace(0, np.nan, inplace=True)
sparse_motif_melt.replace(0, np.nan, inplace=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 10))
ax = sns.scatterplot(data=dense_motif_melt, x='Group', y='Motif', size='P-Value', hue='Cell', palette=cell2color, ax=ax, sizes=(20, 300))
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.xticks(rotation=90)
plt.savefig("dense_Motif_bubblePlot.pdf")

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 20))
ax = sns.scatterplot(data=sparse_motif_melt, x='Group', y='Motif', size='P-Value', hue='Cell', palette=cell2color, ax=ax, sizes=(20, 300))
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.xticks(rotation=90)
plt.savefig("sparse_Motif_bubblePlot.pdf")

# %%
selected_motifs = [x for x in sparse_motif.index if 'RUNX' in x or 'T-box' in x or 'BATF' in x or 'Fra1' in x or 'CTCF' in x or 'Atf3' in x]

# %%
combined_motifs = pd.concat([sparse_motif.loc[selected_motifs], dense_motif])

# %%
combined_motifs
# Out:
#                       hyper_B-Mem_acu  hyper_B-Mem_cro  hyper_B-Mem_pre  \
# Atf3(bZIP)                       -0.0             -0.0             -0.0
# CTCF(Zf)                         -0.0             -0.0             -0.0
# Eomes(T-box)                     -0.0             -0.0             -0.0
# Fra1(bZIP)                       -0.0             -0.0             -0.0
# IRF:BATF(IRF:bZIP)               -0.0             -0.0             -0.0
# RUNX(Runt)                       -0.0             -0.0             -0.0
# RUNX1(Runt)                      -0.0             -0.0             -0.0
# RUNX2(Runt)                      -0.0             -0.0             -0.0
# Tbet(T-box)                      -0.0             -0.0             -0.0
# Tbr1(T-box)                      -0.0             -0.0             -0.0
# Tbx21(T-box)                     -0.0             -0.0             -0.0
# Tbx6(T-box)                      -0.0             -0.0             -0.0
# AP-1(bZIP)                       -0.0             -0.0              3.0
# BATF(bZIP)                       -0.0             -0.0              3.0
# BMAL1(bHLH)                      -0.0              5.0             -0.0
# CLOCK(bHLH)                       5.0              3.0             -0.0
# EHF(ETS)                         -0.0             -0.0              3.0
# ELF3(ETS)                        -0.0             -0.0             -0.0
# ELF5(ETS)                        -0.0             -0.0              3.0
# ERG(ETS)                         -0.0             -0.0              5.0
# ETS1(ETS)                        -0.0             -0.0             -0.0
# ETV1(ETS)                        -0.0             -0.0             -0.0
# ETV4(ETS)                        -0.0             -0.0             -0.0
# EWS:ERG-fusion(ETS)              -0.0             -0.0              4.0
# EWS:FLI1-fusion(ETS)             -0.0             -0.0             -0.0
# Elf4(ETS)                        -0.0             -0.0             -0.0
# Ets1-distal(ETS)                 -0.0             -0.0             -0.0
# Etv2(ETS)                        -0.0             -0.0              3.0
# Fli1(ETS)                        -0.0             -0.0             -0.0
# Fos(bZIP)                         3.0             -0.0              3.0
# Fosl2(bZIP)                      -0.0             -0.0             -0.0
# Fra2(bZIP)                       -0.0             -0.0             -0.0
# HIF-1b(HLH)                      -0.0              3.0             -0.0
# Jun-AP1(bZIP)                    -0.0             -0.0             -0.0
# JunB(bZIP)                       -0.0             -0.0             -0.0
# MNT(bHLH)                        -0.0             -0.0             -0.0
# NPAS(bHLH)                        3.0              5.0             -0.0
# NPAS2(bHLH)                       3.0              4.0             -0.0
# Npas4(bHLH)                      -0.0              3.0              4.0
# PU.1(ETS)                        -0.0             -0.0             -0.0
# RUNX-AML(Runt)                   -0.0             -0.0             -0.0
# USF1(bHLH)                        4.0             -0.0             -0.0
# bHLHE41(bHLH)                    -0.0              4.0              3.0
# c-Myc(bHLH)                       3.0             -0.0             -0.0
# n-Myc(bHLH)                      -0.0             -0.0              3.0
#
#                       hyper_B-Naive_acu  hyper_B-Naive_cro  hyper_B-Naive_pre  \
# Atf3(bZIP)                         -0.0               -0.0               -0.0
# CTCF(Zf)                           -0.0                3.0               -0.0
# Eomes(T-box)                       -0.0               -0.0               -0.0
# Fra1(bZIP)                         -0.0               -0.0               -0.0
# IRF:BATF(IRF:bZIP)                 -0.0               -0.0               -0.0
# RUNX(Runt)                         -0.0               -0.0               -0.0
# RUNX1(Runt)                        -0.0               -0.0               -0.0
# RUNX2(Runt)                        -0.0               -0.0               -0.0
# Tbet(T-box)                        -0.0               -0.0               -0.0
# Tbr1(T-box)                        -0.0               -0.0               -0.0
# Tbx21(T-box)                       -0.0               -0.0               -0.0
# Tbx6(T-box)                        -0.0               -0.0               -0.0
# AP-1(bZIP)                         -0.0               -0.0               -0.0
# BATF(bZIP)                         -0.0               -0.0               -0.0
# BMAL1(bHLH)                        -0.0               -0.0               -0.0
# CLOCK(bHLH)                        -0.0               -0.0               -0.0
# EHF(ETS)                            3.0                3.0               -0.0
# ELF3(ETS)                           3.0               -0.0               -0.0
# ELF5(ETS)                          -0.0               -0.0               -0.0
# ERG(ETS)                            7.0                3.0                3.0
# ETS1(ETS)                           3.0               -0.0               -0.0
# ETV1(ETS)                           3.0                3.0               -0.0
# ETV4(ETS)                           4.0                3.0               -0.0
# EWS:ERG-fusion(ETS)                 4.0                3.0                3.0
# EWS:FLI1-fusion(ETS)               -0.0               -0.0               -0.0
# Elf4(ETS)                           3.0               -0.0               -0.0
# Ets1-distal(ETS)                   -0.0               -0.0               -0.0
# Etv2(ETS)                           3.0                3.0                3.0
# Fli1(ETS)                           3.0                3.0               -0.0
# Fos(bZIP)                          -0.0               -0.0               -0.0
# Fosl2(bZIP)                        -0.0               -0.0               -0.0
# Fra2(bZIP)                         -0.0               -0.0               -0.0
# HIF-1b(HLH)                        -0.0               -0.0               -0.0
# Jun-AP1(bZIP)                      -0.0               -0.0               -0.0
# JunB(bZIP)                         -0.0               -0.0               -0.0
# MNT(bHLH)                          -0.0               -0.0                3.0
# NPAS(bHLH)                         -0.0               -0.0               -0.0
# NPAS2(bHLH)                        -0.0               -0.0               -0.0
# Npas4(bHLH)                        -0.0               -0.0               -0.0
# PU.1(ETS)                           4.0               -0.0               -0.0
# RUNX-AML(Runt)                     -0.0                3.0               -0.0
# USF1(bHLH)                         -0.0               -0.0               -0.0
# bHLHE41(bHLH)                      -0.0               -0.0               -0.0
# c-Myc(bHLH)                        -0.0               -0.0               -0.0
# n-Myc(bHLH)                         3.0               -0.0                3.0
#
#                       hyper_Monocyte_acu  hyper_Monocyte_cro  \
# Atf3(bZIP)                          -0.0                -0.0
# CTCF(Zf)                            -0.0                -0.0
# Eomes(T-box)                        -0.0                -0.0
# Fra1(bZIP)                          -0.0                -0.0
# IRF:BATF(IRF:bZIP)                  -0.0                -0.0
# RUNX(Runt)                          -0.0                -0.0
# RUNX1(Runt)                         -0.0                -0.0
# RUNX2(Runt)                         -0.0                -0.0
# Tbet(T-box)                         -0.0                -0.0
# Tbr1(T-box)                         -0.0                -0.0
# Tbx21(T-box)                        -0.0                -0.0
# Tbx6(T-box)                         -0.0                -0.0
# AP-1(bZIP)                          -0.0                -0.0
# BATF(bZIP)                          -0.0                -0.0
# BMAL1(bHLH)                         -0.0                -0.0
# CLOCK(bHLH)                         -0.0                -0.0
# EHF(ETS)                            10.0                 9.0
# ELF3(ETS)                           11.0                 6.0
# ELF5(ETS)                            5.0                 5.0
# ERG(ETS)                             6.0                10.0
# ETS1(ETS)                            4.0                 9.0
# ETV1(ETS)                            5.0                 5.0
# ETV4(ETS)                            3.0                 4.0
# EWS:ERG-fusion(ETS)                  6.0                 8.0
# EWS:FLI1-fusion(ETS)                -0.0                 4.0
# Elf4(ETS)                            6.0                 4.0
# Ets1-distal(ETS)                    -0.0                -0.0
# Etv2(ETS)                           10.0                 6.0
# Fli1(ETS)                            3.0                 4.0
# Fos(bZIP)                           -0.0                -0.0
# Fosl2(bZIP)                          4.0                -0.0
# Fra2(bZIP)                          -0.0                -0.0
# HIF-1b(HLH)                          3.0                -0.0
# Jun-AP1(bZIP)                       -0.0                -0.0
# JunB(bZIP)                           3.0                -0.0
# MNT(bHLH)                           -0.0                -0.0
# NPAS(bHLH)                           3.0                -0.0
# NPAS2(bHLH)                         -0.0                -0.0
# Npas4(bHLH)                         -0.0                -0.0
# PU.1(ETS)                            7.0                 3.0
# RUNX-AML(Runt)                      -0.0                -0.0
# USF1(bHLH)                          -0.0                -0.0
# bHLHE41(bHLH)                       -0.0                -0.0
# c-Myc(bHLH)                          3.0                -0.0
# n-Myc(bHLH)                         -0.0                -0.0
#
#                       hyper_Monocyte_pre  hyper_NK-cell1_acu  ...  \
# Atf3(bZIP)                          -0.0                -0.0  ...
# CTCF(Zf)                            -0.0                -0.0  ...
# Eomes(T-box)                        -0.0                -0.0  ...
# Fra1(bZIP)                          -0.0                -0.0  ...
# IRF:BATF(IRF:bZIP)                  -0.0                -0.0  ...
# RUNX(Runt)                           3.0                -0.0  ...
# RUNX1(Runt)                         -0.0                -0.0  ...
# RUNX2(Runt)                         -0.0                -0.0  ...
# Tbet(T-box)                         -0.0                -0.0  ...
# Tbr1(T-box)                         -0.0                -0.0  ...
# Tbx21(T-box)                        -0.0                -0.0  ...
# Tbx6(T-box)                         -0.0                -0.0  ...
# AP-1(bZIP)                          -0.0                -0.0  ...
# BATF(bZIP)                          -0.0                -0.0  ...
# BMAL1(bHLH)                          3.0                -0.0  ...
# CLOCK(bHLH)                          6.0                -0.0  ...
# EHF(ETS)                             4.0                -0.0  ...
# ELF3(ETS)                            4.0                -0.0  ...
# ELF5(ETS)                           -0.0                -0.0  ...
# ERG(ETS)                            -0.0                -0.0  ...
# ETS1(ETS)                           -0.0                -0.0  ...
# ETV1(ETS)                           -0.0                -0.0  ...
# ETV4(ETS)                           -0.0                -0.0  ...
# EWS:ERG-fusion(ETS)                 -0.0                -0.0  ...
# EWS:FLI1-fusion(ETS)                -0.0                -0.0  ...
# Elf4(ETS)                           -0.0                -0.0  ...
# Ets1-distal(ETS)                    -0.0                -0.0  ...
# Etv2(ETS)                            3.0                -0.0  ...
# Fli1(ETS)                           -0.0                -0.0  ...
# Fos(bZIP)                           -0.0                -0.0  ...
# Fosl2(bZIP)                         -0.0                -0.0  ...
# Fra2(bZIP)                          -0.0                -0.0  ...
# HIF-1b(HLH)                         -0.0                -0.0  ...
# Jun-AP1(bZIP)                       -0.0                -0.0  ...
# JunB(bZIP)                          -0.0                -0.0  ...
# MNT(bHLH)                           -0.0                -0.0  ...
# NPAS(bHLH)                           3.0                -0.0  ...
# NPAS2(bHLH)                         -0.0                 3.0  ...
# Npas4(bHLH)                         -0.0                10.0  ...
# PU.1(ETS)                           -0.0                -0.0  ...
# RUNX-AML(Runt)                       4.0                -0.0  ...
# USF1(bHLH)                           8.0                 3.0  ...
# bHLHE41(bHLH)                       -0.0                 5.0  ...
# c-Myc(bHLH)                          3.0                 4.0  ...
# n-Myc(bHLH)                          4.0                -0.0  ...
#
#                       hypo_Tc-Naive_acu  hypo_Tc-Naive_cro  hypo_Tc-Naive_pre  \
# Atf3(bZIP)                         -0.0                3.0               -0.0
# CTCF(Zf)                           -0.0               -0.0               -0.0
# Eomes(T-box)                       -0.0               -0.0               -0.0
# Fra1(bZIP)                          4.0               -0.0               -0.0
# IRF:BATF(IRF:bZIP)                 -0.0               -0.0               -0.0
# RUNX(Runt)                         -0.0               -0.0                3.0
# RUNX1(Runt)                         5.0               -0.0               -0.0
# RUNX2(Runt)                         6.0               -0.0               -0.0
# Tbet(T-box)                        -0.0               -0.0               -0.0
# Tbr1(T-box)                        -0.0               -0.0               -0.0
# Tbx21(T-box)                       -0.0               -0.0               -0.0
# Tbx6(T-box)                        -0.0               -0.0               -0.0
# AP-1(bZIP)                          3.0                3.0               -0.0
# BATF(bZIP)                          4.0               -0.0               -0.0
# BMAL1(bHLH)                         8.0                4.0               -0.0
# CLOCK(bHLH)                        10.0               -0.0               -0.0
# EHF(ETS)                           -0.0               -0.0               10.0
# ELF3(ETS)                          -0.0                3.0                7.0
# ELF5(ETS)                          -0.0               -0.0                4.0
# ERG(ETS)                           -0.0                3.0               12.0
# ETS1(ETS)                          -0.0               -0.0               10.0
# ETV1(ETS)                          -0.0               -0.0                8.0
# ETV4(ETS)                          -0.0               -0.0                4.0
# EWS:ERG-fusion(ETS)                -0.0                4.0               10.0
# EWS:FLI1-fusion(ETS)               -0.0                5.0                6.0
# Elf4(ETS)                          -0.0               -0.0                8.0
# Ets1-distal(ETS)                   -0.0               -0.0                8.0
# Etv2(ETS)                          -0.0               -0.0               11.0
# Fli1(ETS)                          -0.0               -0.0                7.0
# Fos(bZIP)                           3.0               -0.0               -0.0
# Fosl2(bZIP)                         4.0               -0.0               -0.0
# Fra2(bZIP)                          4.0               -0.0               -0.0
# HIF-1b(HLH)                        -0.0                3.0               -0.0
# Jun-AP1(bZIP)                       4.0               -0.0               -0.0
# JunB(bZIP)                          6.0               -0.0               -0.0
# MNT(bHLH)                           8.0                4.0               -0.0
# NPAS(bHLH)                         13.0                7.0               -0.0
# NPAS2(bHLH)                         6.0               -0.0               -0.0
# Npas4(bHLH)                         3.0               -0.0               -0.0
# PU.1(ETS)                          -0.0               -0.0                5.0
# RUNX-AML(Runt)                      6.0               -0.0               -0.0
# USF1(bHLH)                          6.0               -0.0               -0.0
# bHLHE41(bHLH)                       5.0               -0.0               -0.0
# c-Myc(bHLH)                         6.0               -0.0               -0.0
# n-Myc(bHLH)                         9.0                3.0               -0.0
#
#                       hypo_Th-Mem_acu  hypo_Th-Mem_cro  hypo_Th-Mem_pre  \
# Atf3(bZIP)                       -0.0             -0.0             -0.0
# CTCF(Zf)                         -0.0             -0.0             -0.0
# Eomes(T-box)                     -0.0             -0.0             -0.0
# Fra1(bZIP)                       -0.0             -0.0             -0.0
# IRF:BATF(IRF:bZIP)               -0.0             -0.0             -0.0
# RUNX(Runt)                       -0.0             -0.0              3.0
# RUNX1(Runt)                      -0.0             -0.0              4.0
# RUNX2(Runt)                      -0.0             -0.0              3.0
# Tbet(T-box)                      -0.0             -0.0             -0.0
# Tbr1(T-box)                      -0.0             -0.0             -0.0
# Tbx21(T-box)                     -0.0             -0.0             -0.0
# Tbx6(T-box)                      -0.0             -0.0             -0.0
# AP-1(bZIP)                       -0.0             -0.0             -0.0
# BATF(bZIP)                       -0.0             -0.0             -0.0
# BMAL1(bHLH)                       3.0             -0.0              3.0
# CLOCK(bHLH)                       5.0             -0.0             -0.0
# EHF(ETS)                         -0.0             -0.0             -0.0
# ELF3(ETS)                        -0.0             -0.0             -0.0
# ELF5(ETS)                        -0.0             -0.0             -0.0
# ERG(ETS)                         -0.0             -0.0             -0.0
# ETS1(ETS)                        -0.0             -0.0             -0.0
# ETV1(ETS)                        -0.0             -0.0             -0.0
# ETV4(ETS)                        -0.0             -0.0             -0.0
# EWS:ERG-fusion(ETS)              -0.0             -0.0             -0.0
# EWS:FLI1-fusion(ETS)             -0.0             -0.0             -0.0
# Elf4(ETS)                        -0.0              3.0             -0.0
# Ets1-distal(ETS)                 -0.0             -0.0             -0.0
# Etv2(ETS)                        -0.0             -0.0             -0.0
# Fli1(ETS)                        -0.0             -0.0             -0.0
# Fos(bZIP)                        -0.0             -0.0             -0.0
# Fosl2(bZIP)                      -0.0             -0.0             -0.0
# Fra2(bZIP)                       -0.0             -0.0             -0.0
# HIF-1b(HLH)                      -0.0             -0.0             -0.0
# Jun-AP1(bZIP)                    -0.0             -0.0             -0.0
# JunB(bZIP)                       -0.0             -0.0             -0.0
# MNT(bHLH)                        -0.0              3.0             -0.0
# NPAS(bHLH)                        7.0             -0.0             -0.0
# NPAS2(bHLH)                       3.0              3.0             -0.0
# Npas4(bHLH)                      -0.0              4.0              3.0
# PU.1(ETS)                        -0.0             -0.0             -0.0
# RUNX-AML(Runt)                   -0.0             -0.0             -0.0
# USF1(bHLH)                        5.0             -0.0             -0.0
# bHLHE41(bHLH)                    -0.0             -0.0             -0.0
# c-Myc(bHLH)                       5.0              3.0              3.0
# n-Myc(bHLH)                       3.0              3.0             -0.0
#
#                       hypo_Th-Naive_acu  hypo_Th-Naive_cro  hypo_Th-Naive_pre  \
# Atf3(bZIP)                         -0.0               -0.0               -0.0
# CTCF(Zf)                            3.0                5.0               -0.0
# Eomes(T-box)                       -0.0               -0.0               -0.0
# Fra1(bZIP)                          3.0               -0.0               -0.0
# IRF:BATF(IRF:bZIP)                 -0.0               -0.0               -0.0
# RUNX(Runt)                         -0.0               -0.0               -0.0
# RUNX1(Runt)                        -0.0               -0.0                4.0
# RUNX2(Runt)                        -0.0               -0.0               -0.0
# Tbet(T-box)                        -0.0               -0.0               -0.0
# Tbr1(T-box)                        -0.0               -0.0               -0.0
# Tbx21(T-box)                       -0.0               -0.0               -0.0
# Tbx6(T-box)                        -0.0               -0.0               -0.0
# AP-1(bZIP)                          3.0               -0.0               -0.0
# BATF(bZIP)                          3.0               -0.0               -0.0
# BMAL1(bHLH)                         3.0               -0.0               -0.0
# CLOCK(bHLH)                         3.0               -0.0               -0.0
# EHF(ETS)                            4.0                6.0               -0.0
# ELF3(ETS)                           5.0                3.0               -0.0
# ELF5(ETS)                           3.0                5.0               -0.0
# ERG(ETS)                            6.0                5.0                3.0
# ETS1(ETS)                           4.0                5.0                3.0
# ETV1(ETS)                           3.0                4.0               -0.0
# ETV4(ETS)                          -0.0               -0.0               -0.0
# EWS:ERG-fusion(ETS)                 6.0                3.0               -0.0
# EWS:FLI1-fusion(ETS)                3.0               -0.0               -0.0
# Elf4(ETS)                           5.0                5.0                3.0
# Ets1-distal(ETS)                   -0.0                4.0                4.0
# Etv2(ETS)                           6.0                5.0                5.0
# Fli1(ETS)                          -0.0                4.0               -0.0
# Fos(bZIP)                           4.0               -0.0               -0.0
# Fosl2(bZIP)                         3.0               -0.0               -0.0
# Fra2(bZIP)                         -0.0               -0.0               -0.0
# HIF-1b(HLH)                        -0.0               -0.0               -0.0
# Jun-AP1(bZIP)                       3.0               -0.0               -0.0
# JunB(bZIP)                          3.0               -0.0               -0.0
# MNT(bHLH)                          -0.0               -0.0               -0.0
# NPAS(bHLH)                          6.0               -0.0               -0.0
# NPAS2(bHLH)                        -0.0               -0.0               -0.0
# Npas4(bHLH)                         3.0               -0.0               -0.0
# PU.1(ETS)                          -0.0               -0.0               -0.0
# RUNX-AML(Runt)                     -0.0               -0.0               -0.0
# USF1(bHLH)                         -0.0               -0.0               -0.0
# bHLHE41(bHLH)                      -0.0               -0.0               -0.0
# c-Myc(bHLH)                         3.0               -0.0               -0.0
# n-Myc(bHLH)                         3.0               -0.0               -0.0
#
#                                      Motif
# Atf3(bZIP)                      Atf3(bZIP)
# CTCF(Zf)                          CTCF(Zf)
# Eomes(T-box)                  Eomes(T-box)
# Fra1(bZIP)                      Fra1(bZIP)
# IRF:BATF(IRF:bZIP)      IRF:BATF(IRF:bZIP)
# RUNX(Runt)                      RUNX(Runt)
# RUNX1(Runt)                    RUNX1(Runt)
# RUNX2(Runt)                    RUNX2(Runt)
# Tbet(T-box)                    Tbet(T-box)
# Tbr1(T-box)                    Tbr1(T-box)
# Tbx21(T-box)                  Tbx21(T-box)
# Tbx6(T-box)                    Tbx6(T-box)
# AP-1(bZIP)                      AP-1(bZIP)
# BATF(bZIP)                      BATF(bZIP)
# BMAL1(bHLH)                    BMAL1(bHLH)
# CLOCK(bHLH)                    CLOCK(bHLH)
# EHF(ETS)                          EHF(ETS)
# ELF3(ETS)                        ELF3(ETS)
# ELF5(ETS)                        ELF5(ETS)
# ERG(ETS)                          ERG(ETS)
# ETS1(ETS)                        ETS1(ETS)
# ETV1(ETS)                        ETV1(ETS)
# ETV4(ETS)                        ETV4(ETS)
# EWS:ERG-fusion(ETS)    EWS:ERG-fusion(ETS)
# EWS:FLI1-fusion(ETS)  EWS:FLI1-fusion(ETS)
# Elf4(ETS)                        Elf4(ETS)
# Ets1-distal(ETS)          Ets1-distal(ETS)
# Etv2(ETS)                        Etv2(ETS)
# Fli1(ETS)                        Fli1(ETS)
# Fos(bZIP)                        Fos(bZIP)
# Fosl2(bZIP)                    Fosl2(bZIP)
# Fra2(bZIP)                      Fra2(bZIP)
# HIF-1b(HLH)                    HIF-1b(HLH)
# Jun-AP1(bZIP)                Jun-AP1(bZIP)
# JunB(bZIP)                      JunB(bZIP)
# MNT(bHLH)                        MNT(bHLH)
# NPAS(bHLH)                      NPAS(bHLH)
# NPAS2(bHLH)                    NPAS2(bHLH)
# Npas4(bHLH)                    Npas4(bHLH)
# PU.1(ETS)                        PU.1(ETS)
# RUNX-AML(Runt)              RUNX-AML(Runt)
# USF1(bHLH)                      USF1(bHLH)
# bHLHE41(bHLH)                bHLHE41(bHLH)
# c-Myc(bHLH)                    c-Myc(bHLH)
# n-Myc(bHLH)                    n-Myc(bHLH)
#
# [45 rows x 55 columns]

# %%
new_motif_ids = [f'{x.split("(")[1]}_{x.split("(")[0]}' for x in combined_motifs.index]
new_motif_ids = [re.sub("\)", "", x) for x in new_motif_ids]

# %%
combined_motifs = combined_motifs.rename(index=dict(zip(combined_motifs.index, new_motif_ids)))
combined_motifs = combined_motifs.sort_index()

# %%
combined_motifs['Motif'] = combined_motifs.index
combine_motif_melt = combined_motifs.melt(var_name='Group', id_vars='Motif', value_name='P-Value')
combine_motif_melt['Cell'] = [x.split("_")[1] for x in combine_motif_melt['Group']]

# %%
combine_motif_melt.replace(0, np.nan, inplace=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 12))
ax = sns.scatterplot(data=combine_motif_melt, x='Group', y='Motif', size='P-Value', hue='Cell', palette=cell2color, ax=ax, sizes=(20, 300))
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.xticks(rotation=90)
plt.savefig("combine_Motif_bubblePlot.pdf")
