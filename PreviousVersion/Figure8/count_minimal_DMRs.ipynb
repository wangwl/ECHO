# %%
import os
import re
import glob
import pandas as pd
from collections import defaultdict, Counter

# %%
prediction_files = glob.glob("*/*/prediction_report.tsv")

# %%
for file in prediction_files:
    outdir = os.path.dirname(file)
    predict_df = pd.read_csv(file, sep="\t", index_col=0)
    auc_keys = [x for x in predict_df.columns if 'auc' in x]
    auc_df = predict_df[auc_keys]
    new_keys = [re.sub("_auc", "", x) for x in auc_keys]
    auc_df = auc_df.rename(columns=dict(zip(auc_df.columns, new_keys)))
    auc_df.to_csv(f"{outdir}/roc_auc.tsv", sep="\t")

# %%
auc_files = glob.glob("*/*/roc_auc.tsv")

# %%
all_dmrs = glob.glob("*/*/DML_All.importance.tsv")
total_dmrs = defaultdict(dict)
for dmrfile in all_dmrs:
    dmr_df = pd.read_csv(dmrfile, names=['id', 'weight'])
    expo, cell = dmrfile.split("/")[:2]
    expo = re.sub("[0-9]+\.", "", expo)
    total_dmrs[expo][cell] = dmr_df.shape[0]

# %%
minimun_dmrs = defaultdict(dict)
for aucfile in auc_files:
    auc_df = pd.read_csv(aucfile, sep="\t", index_col=0)
    expo_dir, cell = aucfile.split("/")[:2]
    expo = re.sub("[0-9]+\.", "", expo_dir)
    conditions = auc_df.columns
    
    found_minimun = dict()
    for percentage, row in auc_df.sort_index().iterrows():
        for cond in conditions:
            if row[cond] >= 0.95 and cond not in found_minimun:
                weight_df = pd.read_csv(f"{expo_dir}/{cell}/DML_Percent{percentage}0.0.importance.tsv", sep="\t", names=['id', 'weight'])
                weight_df = weight_df[weight_df['weight']!=0]
                minimum_dmr = weight_df.shape[0]
                minimun_dmrs[f'{expo}_{cond}'][cell] = minimum_dmr
                found_minimun[cond] = 1

# %%
minimun_dmrs_df = pd.DataFrame.from_dict(minimun_dmrs, orient='index')

# %%
minimun_dmrs_df
# Out:
#                 B-Mem  B-Naive  Monocyte  NK-cell1  NK-cell2  Tc-Mem  \
# HIV_cro         492.0    371.0     684.0     398.0     394.0   742.0
# HIV_pre         492.0    208.0     385.0     398.0     394.0   742.0
# HIV_acu         836.0    260.0     230.0     398.0     246.0   742.0
# MRSA_Ctrl       289.0    188.0     444.0     230.0     257.0   485.0
# MRSA_MRSA       289.0    188.0     444.0     493.0     257.0   485.0
# MRSA_MSSA       289.0    188.0     444.0     376.0     650.0   485.0
# BA_Ctrl         265.0    100.0     239.0     262.0     146.0   331.0
# BA_frequent     265.0    100.0     239.0       NaN     375.0   331.0
# BA_unfrequent   643.0    188.0     239.0     262.0     375.0   331.0
# OP_Ctrl         468.0    474.0     758.0     479.0     480.0  1214.0
# OP_Low          793.0    812.0       NaN     479.0     875.0  1214.0
# OP_High        1066.0    474.0       NaN       NaN    2146.0  2106.0
# COVID_C         426.0    232.0    1096.0     251.0     262.0   482.0
# COVID_Ctrl      426.0    232.0    1096.0     251.0     262.0   482.0
# COVID_W         426.0    232.0    1096.0     643.0     262.0   482.0
# OP_Med            NaN      NaN       NaN       NaN       NaN     NaN
#
#                Tc-Naive  Th-Mem  Th-Naive
# HIV_cro           346.0   491.0     189.0
# HIV_pre           346.0   491.0     189.0
# HIV_acu           346.0   491.0     189.0
# MRSA_Ctrl         485.0   485.0     530.0
# MRSA_MRSA         485.0   485.0     530.0
# MRSA_MSSA         485.0   485.0     530.0
# BA_Ctrl           241.0   256.0     235.0
# BA_frequent       241.0   256.0     235.0
# BA_unfrequent     241.0   739.0     235.0
# OP_Ctrl           635.0   769.0     808.0
# OP_Low              NaN  3094.0     808.0
# OP_High           635.0     NaN       NaN
# COVID_C           650.0   477.0    1029.0
# COVID_Ctrl        650.0   477.0    1029.0
# COVID_W           650.0   477.0    1029.0
# OP_Med            635.0  2598.0     808.0

# %%
auc_df = pd.read_csv("06.Flu/roc_auc.tsv", sep="\t", index_col=0)

# %%
expo = 'Flu'
expo_dir = '06.Flu'
celltypes = auc_df.columns

for celltype in celltypes:
    found_minimun = 0
    for percentage, row in auc_df.sort_index().iterrows():
        if row[celltype] >= 0.95 and found_minimun == 0:
            weight_df = pd.read_csv(f"{expo_dir}/{celltype}/Flu_{celltype}_minimal_DMRs_weight.bed", sep="\t", names=['id', 'weight'])
            minimum_dmr = weight_df.shape[0]
            minimun_dmrs[f'{expo}'][celltype] = minimum_dmr
            found_minimun = 1

# %%
minimun_dmrs_df = pd.DataFrame.from_dict(minimun_dmrs, orient='index')

# %%
minimun_dmrs_df
# Out:
#                 B-Mem  B-Naive  Monocyte  NK-cell1  NK-cell2  Tc-Mem  \
# HIV_cro         492.0    371.0     684.0     398.0     394.0   742.0
# HIV_pre         492.0    208.0     385.0     398.0     394.0   742.0
# HIV_acu         836.0    260.0     230.0     398.0     246.0   742.0
# MRSA_Ctrl       289.0    188.0     444.0     230.0     257.0   485.0
# MRSA_MRSA       289.0    188.0     444.0     493.0     257.0   485.0
# MRSA_MSSA       289.0    188.0     444.0     376.0     650.0   485.0
# BA_Ctrl         265.0    100.0     239.0     262.0     146.0   331.0
# BA_frequent     265.0    100.0     239.0       NaN     375.0   331.0
# BA_unfrequent   643.0    188.0     239.0     262.0     375.0   331.0
# OP_Ctrl         468.0    474.0     758.0     479.0     480.0  1214.0
# OP_Low          793.0    812.0       NaN     479.0     875.0  1214.0
# OP_High        1066.0    474.0       NaN       NaN    2146.0  2106.0
# COVID_C         426.0    232.0    1096.0     251.0     262.0   482.0
# COVID_Ctrl      426.0    232.0    1096.0     251.0     262.0   482.0
# COVID_W         426.0    232.0    1096.0     643.0     262.0   482.0
# Flu             313.0    186.0     186.0       NaN     299.0   405.0
# OP_Med            NaN      NaN       NaN       NaN       NaN     NaN
#
#                Tc-Naive  Th-Mem  Th-Naive
# HIV_cro           346.0   491.0     189.0
# HIV_pre           346.0   491.0     189.0
# HIV_acu           346.0   491.0     189.0
# MRSA_Ctrl         485.0   485.0     530.0
# MRSA_MRSA         485.0   485.0     530.0
# MRSA_MSSA         485.0   485.0     530.0
# BA_Ctrl           241.0   256.0     235.0
# BA_frequent       241.0   256.0     235.0
# BA_unfrequent     241.0   739.0     235.0
# OP_Ctrl           635.0   769.0     808.0
# OP_Low              NaN  3094.0     808.0
# OP_High           635.0     NaN       NaN
# COVID_C           650.0   477.0    1029.0
# COVID_Ctrl        650.0   477.0    1029.0
# COVID_W           650.0   477.0    1029.0
# Flu               112.0   327.0     138.0
# OP_Med            635.0  2598.0     808.0

# %%
minimun_dmrs_df.to_csv("minimum_number_of_DMRs.tsv")

# %%
mimimun_dmr_files = glob.glob(f'*/*/*_minimal_DMRs_weight.bed')

# %%
for dmrfile in mimimun_dmr_files:
    weight_df = pd.read_csv(dmrfile, sep="\t", names=['chrom', 'start', 'end', 'id', 'weight'])
    expo, cel
# Out:
# ['01.HIV/B-Mem/HIV_B-Mem_minimal_DMRs_weight.bed',
#  '01.HIV/B-Naive/HIV_B-Naive_minimal_DMRs_weight.bed',
#  '01.HIV/Monocyte/HIV_Monocyte_minimal_DMRs_weight.bed',
#  '01.HIV/NK-cell1/HIV_NK-cell1_minimal_DMRs_weight.bed',
#  '01.HIV/NK-cell2/HIV_NK-cell2_minimal_DMRs_weight.bed',
#  '01.HIV/Tc-Mem/HIV_Tc-Mem_minimal_DMRs_weight.bed',
#  '01.HIV/Tc-Naive/HIV_Tc-Naive_minimal_DMRs_weight.bed',
#  '01.HIV/Th-Mem/HIV_Th-Mem_minimal_DMRs_weight.bed',
#  '01.HIV/Th-Naive/HIV_Th-Naive_minimal_DMRs_weight.bed',
#  '02.MRSA/B-Mem/MRSA_B-Mem_minimal_DMRs_weight.bed',
#  '02.MRSA/B-Naive/MRSA_B-Naive_minimal_DMRs_weight.bed',
#  '02.MRSA/Monocyte/MRSA_Monocyte_minimal_DMRs_weight.bed',
#  '02.MRSA/NK-cell1/MRSA_NK-cell1_minimal_DMRs_weight.bed',
#  '02.MRSA/NK-cell2/MRSA_NK-cell2_minimal_DMRs_weight.bed',
#  '02.MRSA/Tc-Mem/MRSA_Tc-Mem_minimal_DMRs_weight.bed',
#  '02.MRSA/Tc-Naive/MRSA_Tc-Naive_minimal_DMRs_weight.bed',
#  '02.MRSA/Th-Mem/MRSA_Th-Mem_minimal_DMRs_weight.bed',
#  '02.MRSA/Th-Naive/MRSA_Th-Naive_minimal_DMRs_weight.bed',
#  '03.BA/B-Mem/BA_B-Mem_minimal_DMRs_weight.bed',
#  '03.BA/B-Naive/BA_B-Naive_minimal_DMRs_weight.bed',
#  '03.BA/Monocyte/BA_Monocyte_minimal_DMRs_weight.bed',
#  '03.BA/NK-cell1/BA_NK-cell1_minimal_DMRs_weight.bed',
#  '03.BA/NK-cell2/BA_NK-cell2_minimal_DMRs_weight.bed',
#  '03.BA/Tc-Mem/BA_Tc-Mem_minimal_DMRs_weight.bed',
#  '03.BA/Tc-Naive/BA_Tc-Naive_minimal_DMRs_weight.bed',
#  '03.BA/Th-Mem/BA_Th-Mem_minimal_DMRs_weight.bed',
#  '03.BA/Th-Naive/BA_Th-Naive_minimal_DMRs_weight.bed',
#  '04.OP/B-Mem/OP_B-Mem_minimal_DMRs_weight.bed',
#  '04.OP/B-Naive/OP_B-Naive_minimal_DMRs_weight.bed',
#  '04.OP/Monocyte/OP_Monocyte_minimal_DMRs_weight.bed',
#  '04.OP/NK-cell1/OP_NK-cell1_minimal_DMRs_weight.bed',
#  '04.OP/NK-cell2/OP_NK-cell2_minimal_DMRs_weight.bed',
#  '04.OP/Tc-Mem/OP_Tc-Mem_minimal_DMRs_weight.bed',
#  '04.OP/Tc-Naive/OP_Tc-Naive_minimal_DMRs_weight.bed',
#  '04.OP/Th-Mem/OP_Th-Mem_minimal_DMRs_weight.bed',
#  '04.OP/Th-Naive/OP_Th-Naive_minimal_DMRs_weight.bed',
#  '05.COVID/B-Mem/COVID_B-Mem_minimal_DMRs_weight.bed',
#  '05.COVID/B-Naive/COVID_B-Naive_minimal_DMRs_weight.bed',
#  '05.COVID/Monocyte/COVID_Monocyte_minimal_DMRs_weight.bed',
#  '05.COVID/NK-cell1/COVID_NK-cell1_minimal_DMRs_weight.bed',
#  '05.COVID/NK-cell2/COVID_NK-cell2_minimal_DMRs_weight.bed',
#  '05.COVID/Tc-Mem/COVID_Tc-Mem_minimal_DMRs_weight.bed',
#  '05.COVID/Tc-Naive/COVID_Tc-Naive_minimal_DMRs_weight.bed',
#  '05.COVID/Th-Mem/COVID_Th-Mem_minimal_DMRs_weight.bed',
#  '05.COVID/Th-Naive/COVID_Th-Naive_minimal_DMRs_weight.bed',
#  '06.Flu/B-Mem/Flu_B-Mem_minimal_DMRs_weight.bed',
#  '06.Flu/B-Naive/Flu_B-Naive_minimal_DMRs_weight.bed',
#  '06.Flu/Monocyte/Flu_Monocyte_minimal_DMRs_weight.bed',
#  '06.Flu/NK-cell2/Flu_NK-cell2_minimal_DMRs_weight.bed',
#  '06.Flu/Tc-Mem/Flu_Tc-Mem_minimal_DMRs_weight.bed',
#  '06.Flu/Tc-Naive/Flu_Tc-Naive_minimal_DMRs_weight.bed',
#  '06.Flu/Th-Mem/Flu_Th-Mem_minimal_DMRs_weight.bed',
#  '06.Flu/Th-Naive/Flu_Th-Naive_minimal_DMRs_weight.bed']
